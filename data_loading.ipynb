# %%
import pandas as pd
from pathlib import Path
import requests
from tqdm import tqdm

# %%
DATA_DIR = Path("data")

all_symbols = pd.read_csv(DATA_DIR / "all_symbols.csv")

# %%
all_symbols
# Out:
#            0
# 0        MRX
# 1        JOB
# 2     WALLET
# 3        MSB
# 4      XCHNG
# ...      ...
# 1422     MCB
# 1423      HT
# 1424      AE
# 1425   DIONE
# 1426     ONE
#
# [1427 rows x 1 columns]

# %%
import requests
import pandas as pd


def query_subgraph(url, token_symbol):
    query = f"""
    {{
        tokens(where: {{symbol: "{token_symbol}"}}) {{
            id
            symbol
            name
            totalValueLockedUSD
            whitelistPools {{
                id
                token0 {{
                    id
                    symbol
                    name
                }}
                token1 {{
                    id
                    symbol
                    name
                }}
            volumeUSD
            }}
        }}
    }}
    """
    response = requests.post(url, json={"query": query})
    if response.status_code == 200:
        return response.json()
    else:
        return None


# List of token symbols to search
token_symbols = [
    # "USDC",
    "WBTC",
    #  'ETH', 'BNB', 'SOL', 'XRP', 'DOGE', 'TON', 'ADA', 'AVAX',
    #     'SHIB', 'TRX', 'LINK', 'DOT', 'BCH', 'NEAR', 'UNI', 'MATIC', 'LTC',
    #     'LEO', 'PEPE', 'ICP', 'KAS', 'ETC', 'APT', 'XMR', 'RNDR', 'HBAR',
    #     'XLM', 'ATOM', 'ARB', 'OKB', 'FIL', 'CRO', 'STX', 'IMX', 'MKR',
    #     'SUI', 'VET', 'GRT', 'OP', 'TAO'
]

subgraphs = {
    "Ethereum Mainnet": "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3",
    # 'Polygon': "https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-polygon",
    #'Optimism': "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3-optimism"
    # Add more chains as needed
}

results = []
for token_symbol in tqdm(token_symbols):
    for chain, url in subgraphs.items():
        data = query_subgraph(url, token_symbol)
        if data and data.get("data", {}).get("tokens"):
            tokens = data["data"]["tokens"]
            for token in tokens:
                for pool in token["whitelistPools"]:
                    results.append(
                        {
                            "Chain": chain,
                            "Token Symbol": token["symbol"],
                            "Token Name": token["name"],
                            "Token ID": token["id"],
                            "Pool ID": pool["id"],
                            "Token0 ID": pool["token0"]["id"],
                            "Token0 Symbol": pool["token0"]["symbol"],
                            "Token0 Name": pool["token0"]["name"],
                            "Token1 ID": pool["token1"]["id"],
                            "Token1 Symbol": pool["token1"]["symbol"],
                            "Token1 Name": pool["token1"]["name"],
                            "Volume USD": int(pool["volumeUSD"]),
                            "TVL USD": int(token["totalValueLockedUSD"]),
                        }
                    )

df = pd.DataFrame(results)
# Optionally, save the DataFrame to a CSV file
# df.to_csv('uniswap_pools.csv', index=False)

# %%
df.sort_values("Volume USD", ascending=False)
# Out:
#                Chain Token Symbol                   Token Name  \
# 6   Ethereum Mainnet         WBTC                  Wrapped BTC
# 19  Ethereum Mainnet         WBTC                  Wrapped BTC
# 14  Ethereum Mainnet         WBTC                  Wrapped BTC
# 15  Ethereum Mainnet         WBTC                  Wrapped BTC
# 16  Ethereum Mainnet         WBTC                  Wrapped BTC
# 4   Ethereum Mainnet         WBTC                  Wrapped BTC
# 11  Ethereum Mainnet         WBTC                  Wrapped BTC
# 7   Ethereum Mainnet         WBTC                  Wrapped BTC
# 22  Ethereum Mainnet         WBTC                  Wrapped BTC
# 17  Ethereum Mainnet         WBTC                  Wrapped BTC
# 20  Ethereum Mainnet         WBTC                  Wrapped BTC
# 13  Ethereum Mainnet         WBTC                  Wrapped BTC
# 10  Ethereum Mainnet         WBTC                  Wrapped BTC
# 12  Ethereum Mainnet         WBTC                  Wrapped BTC
# 24  Ethereum Mainnet         WBTC              Wrapped Bitcoin
# 21  Ethereum Mainnet         WBTC                  Wrapped BTC
# 8   Ethereum Mainnet         WBTC                  Wrapped BTC
# 18  Ethereum Mainnet         WBTC                  Wrapped BTC
# 2   Ethereum Mainnet         WBTC                  Wrapped BTC
# 1   Ethereum Mainnet         WBTC                  Wrapped BTC
# 3   Ethereum Mainnet         WBTC                  Wrapped BTC
# 5   Ethereum Mainnet         WBTC                  Wrapped BTC
# 9   Ethereum Mainnet         WBTC                  Wrapped BTC
# 26  Ethereum Mainnet         WBTC                  Wrapped BTC
# 25  Ethereum Mainnet         WBTC                  Wrapped BTC
# 0   Ethereum Mainnet         WBTC                  Wrapped BTC
# 23  Ethereum Mainnet         WBTC  Wrapped BTC from PulseChain
#
#                                       Token ID  \
# 6   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 19  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 14  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 15  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 16  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 4   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 11  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 7   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 22  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 17  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 20  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 13  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 10  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 12  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 24  0x476908d9f75687684ce3dbf6990e722129cdbcc6
# 21  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 8   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 18  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 2   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 1   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 3   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 5   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 9   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 26  0xbba44cc50186569af7b8e1a1fe181612a2d1f49d
# 25  0xb83fbac785f5cd4a15a8e922b31c0148316aadf7
# 0   0x110c472ab8773ae3fc8588479e9f21e0fc3e845b
# 23  0x2741537d43f3d146c4130bca3ed99821915354bb
#
#                                        Pool ID  \
# 6   0x4585fe77225b41b697c938b018e2ac67ac5a20c0
# 19  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed
# 14  0x99ac8ca7087fa4a2a1fb6357269965a2014abc35
# 15  0x9a772018fbd77fcd2d25657e5c547baff3fd7d16
# 16  0x9db9e0e53058c89e5b94e29621a205198648425b
# 4   0x391e8501b626c623d39474afca6f9e46c2686649
# 11  0x6ab3bba2f41e7eaa262fa5a1a9b3932fa161526f
# 7   0x56534741cd8b152df6d48adf7ac51f75169a83b2
# 22  0xe6ff8b9a37b0fab776134636d9981aa778c4e718
# 17  0xa93eb5b410b651514a18724872306f5ce9928dde
# 20  0xcbfb0745b8489973bf7b334d54fdbd573df7ef3c
# 13  0x98e45940d0c76898f5659b8fc78895f35a39eb43
# 10  0x649caaf37f36e67d1129c0fd6c6539d390ca2b82
# 12  0x775d0c18b291b889ab3d7f16338183bbfaf63f7a
# 24  0x2858840e4f5e7d004f945da9e0847514563ed802
# 21  0xd92de63661d2e298350307a63fea2c3f1731ff9a
# 8   0x5a59e4e647a3acc42b01715f3a1d271c1f7e7aeb
# 18  0xc50ba3939b29fb9872606517deb5fc8937b39261
# 2   0x15c11b1e07cb763ab75723bb55877b36f56c39b1
# 1   0x026babd2ae9379525030fc2574e39bc156c10583
# 3   0x1e5143bb68abfadc401360a55e8aca2fd292b673
# 5   0x3bb14627714a2b64b709e16c96d5e3ad8448ab56
# 9   0x618004783d422dfb792d07d742549d5a24648df2
# 26  0xa2367832bacd3d8f06a5b20f468dd15a9451068d
# 25  0x5df47f5d51254e7ab12a45c9f5d7d5cc91305af7
# 0   0x8f333d9a6f4cf8518b2899bb5aaf67c29225e6c6
# 23  0x90e089a7f34e8954d972ec9a4ebdca6196dd649e
#
#                                      Token0 ID Token0 Symbol  \
# 6   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 19  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 14  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 15  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 16  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 4   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 11  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 7   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 22  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 17  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 20  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 13  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 10  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 12  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e           YFI
# 24  0x476908d9f75687684ce3dbf6990e722129cdbcc6          WBTC
# 21  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 8   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 18  0x111111111117dc0aa78b770fa6a738034120c302         1INCH
# 2   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 1   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 3   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 5   0x111111111117dc0aa78b770fa6a738034120c302         1INCH
# 9   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 26  0xbba44cc50186569af7b8e1a1fe181612a2d1f49d          WBTC
# 25  0xb83fbac785f5cd4a15a8e922b31c0148316aadf7          WBTC
# 0   0x110c472ab8773ae3fc8588479e9f21e0fc3e845b          WBTC
# 23  0x2741537d43f3d146c4130bca3ed99821915354bb          WBTC
#
#                     Token0 Name                                   Token1 ID  \
# 6                   Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 19                  Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 14                  Wrapped BTC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 15                  Wrapped BTC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 16                  Wrapped BTC  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4                   Wrapped BTC  0x6b175474e89094c44da98b954eedeac495271d0f
# 11                  Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 7                   Wrapped BTC  0xdac17f958d2ee523a2206206994597c13d831ec7
# 22                  Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 17                  Wrapped BTC  0x6b175474e89094c44da98b954eedeac495271d0f
# 20                  Wrapped BTC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 13                  Wrapped BTC  0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9
# 10                  Wrapped BTC  0x6b175474e89094c44da98b954eedeac495271d0f
# 12                yearn.finance  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 24              Wrapped Bitcoin  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 21                  Wrapped BTC  0xc00e94cb662c3520282e6f5717214004a7f26888
# 8                   Wrapped BTC  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18                  1INCH Token  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 2                   Wrapped BTC  0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f
# 1                   Wrapped BTC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                   Wrapped BTC  0xc00e94cb662c3520282e6f5717214004a7f26888
# 5                   1INCH Token  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 9                   Wrapped BTC  0x514910771af9ca656af840dff83e8264ecf986ca
# 26                  Wrapped BTC  0xdac17f958d2ee523a2206206994597c13d831ec7
# 25                  Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 0                   Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 23  Wrapped BTC from PulseChain  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#    Token1 Symbol              Token1 Name    Volume USD       TVL USD
# 6           WETH            Wrapped Ether  6.782025e+10  3.587374e+08
# 19          WETH            Wrapped Ether  2.850329e+10  3.587374e+08
# 14          USDC                 USD Coin  1.387184e+10  3.587374e+08
# 15          USDC                 USD Coin  4.390350e+09  3.587374e+08
# 16          USDT               Tether USD  2.784883e+09  3.587374e+08
# 4            DAI           Dai Stablecoin  1.377940e+08  3.587374e+08
# 11          WETH            Wrapped Ether  7.084776e+07  3.587374e+08
# 7           USDT               Tether USD  4.202397e+07  3.587374e+08
# 22          WETH            Wrapped Ether  2.592876e+07  3.587374e+08
# 17           DAI           Dai Stablecoin  1.638911e+07  3.587374e+08
# 20          USDC                 USD Coin  1.027603e+07  3.587374e+08
# 13          AAVE               Aave Token  3.243511e+06  3.587374e+08
# 10           DAI           Dai Stablecoin  2.712566e+06  3.587374e+08
# 12          WBTC              Wrapped BTC  2.218393e+06  3.587374e+08
# 24          WETH            Wrapped Ether  1.890626e+06  0.000000e+00
# 21          COMP                 Compound  1.302458e+06  3.587374e+08
# 8           USDT               Tether USD  7.871213e+05  3.587374e+08
# 18          WBTC              Wrapped BTC  7.630119e+05  3.587374e+08
# 2            SNX  Synthetix Network Token  4.374002e+05  3.587374e+08
# 1           USDC                 USD Coin  3.276979e+05  3.587374e+08
# 3           COMP                 Compound  3.027852e+05  3.587374e+08
# 5           WBTC              Wrapped BTC  1.925319e+05  3.587374e+08
# 9           LINK          ChainLink Token  1.102459e+05  3.587374e+08
# 26          USDT               Tether USD  4.526167e+01  0.000000e+00
# 25          WETH            Wrapped Ether  4.238140e-02  0.000000e+00
# 0           WETH            Wrapped Ether  3.588531e-04  0.000000e+00
# 23          WETH            Wrapped Ether  0.000000e+00  0.000000e+00
