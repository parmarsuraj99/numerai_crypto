# %%
import pandas as pd
from pathlib import Path
import requests
from tqdm import tqdm

# %%
DATA_DIR = Path("data")

all_symbols = pd.read_csv(DATA_DIR / "all_symbols.csv").rename(columns={"0": "symbol"})

# %%
all_symbols
# Out:
#       symbol
# 0        MRX
# 1        JOB
# 2     WALLET
# 3        MSB
# 4      XCHNG
# ...      ...
# 1422     MCB
# 1423      HT
# 1424      AE
# 1425   DIONE
# 1426     ONE
#
# [1427 rows x 1 columns]

# %%
import requests
import pandas as pd


def query_subgraph(url, token_symbol):
    query = f"""
    {{
        tokens(where: {{symbol: "{token_symbol}"}}) {{
            id
            symbol
            name
            totalValueLockedUSD
            whitelistPools {{
                id
                token0 {{
                    id
                    symbol
                    name
                }}
                token1 {{
                    id
                    symbol
                    name
                }}
            volumeUSD
            }}
        }}
    }}
    """
    response = requests.post(url, json={"query": query})
    if response.status_code == 200:
        return response.json()
    else:
        return None


# List of token symbols to search
token_symbols = [
    "USDC",
    "WBTC",
    "ETH",
    "WETH",
    "wTAO",
] + all_symbols[
    "symbol"
].tolist()  # [:200]

subgraphs = {
    "Ethereum Mainnet": "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3",
    # 'Polygon': "https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-polygon",
    #'Optimism': "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3-optimism"
    # Add more chains as needed
}

results = []
for token_symbol in tqdm(token_symbols):
    for chain, url in subgraphs.items():
        data = query_subgraph(url, token_symbol)
        if data and data.get("data", {}).get("tokens"):
            tokens = data["data"]["tokens"]
            for token in tokens:
                for pool in token["whitelistPools"]:
                    results.append(
                        {
                            "Chain": chain,
                            "Token Symbol": token["symbol"],
                            "Token Name": token["name"],
                            "Token ID": token["id"],
                            "Pool ID": pool["id"],
                            "Token0 ID": pool["token0"]["id"],
                            "Token0 Symbol": pool["token0"]["symbol"],
                            "Token0 Name": pool["token0"]["name"],
                            "Token1 ID": pool["token1"]["id"],
                            "Token1 Symbol": pool["token1"]["symbol"],
                            "Token1 Name": pool["token1"]["name"],
                            "Volume USD": float(pool["volumeUSD"]),
                            "TVL USD": float(token["totalValueLockedUSD"]),
                        }
                    )

df = pd.DataFrame(results)
df = df.drop_duplicates(subset=["Pool ID"])

# remove 0 tvl adn volume
df = df[df["TVL USD"] > 0]
df = df[df["Volume USD"] > 0]

df["Pool Name"] = df["Token0 Symbol"] + "/" + df["Token1 Symbol"]

# Optionally, save the DataFrame to a CSV file
# df.to_csv('uniswap_pools.csv', index=False)
# Out:
#  22%|██▏       | 319/1432 [01:56<06:57,  2.66it/s]

# %%
df
# Out:
#                 Chain Token Symbol  \
# 3    Ethereum Mainnet         USDC
# 8    Ethereum Mainnet         USDC
# 9    Ethereum Mainnet         USDC
# 10   Ethereum Mainnet         USDC
# 11   Ethereum Mainnet         USDC
# ..                ...          ...
# 524  Ethereum Mainnet         PERP
# 525  Ethereum Mainnet         PERP
# 526  Ethereum Mainnet         PERP
# 527  Ethereum Mainnet         PERP
# 528  Ethereum Mainnet          SUI
#
#                                             Token Name  \
# 3                            USD Coin (PoS) (Wormhole)
# 8    UltraSuperfuckingDementedgreendildoretardstren...
# 9                                             USD Coin
# 10                                            USD Coin
# 11                                            USD Coin
# ..                                                 ...
# 524                                          Perpetual
# 525                                          Perpetual
# 526                                          Perpetual
# 527                                          Perpetual
# 528                                        SUI Network
#
#                                        Token ID  \
# 3    0x566957ef80f9fd5526cd2bef8be67035c0b81130
# 8    0x9abc68b33961268a3ea4116214d7039226de01e1
# 9    0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 10   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 11   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                                          ...
# 524  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 525  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 526  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 527  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 528  0x5c839a10cba8db5122179b05c2135ac8f41038ce
#
#                                         Pool ID  \
# 3    0xd376814cd28dcb6f30553e5026708ec9d6b9a8dc
# 8    0x07a72f8f6a29cf501e7226ca82264f9ee79380e7
# 9    0x020c349a0541d76c16f501abc6b2e9c98adae892
# 10   0x026babd2ae9379525030fc2574e39bc156c10583
# 11   0x07a6e955ba4345bae83ac2a6faa771fddd8a2011
# ..                                          ...
# 524  0x56027930bdff39faf295a7cf6bb94b9bb9f6a718
# 525  0xad25a15d9059a8d3163acbbe6a98119fc63afbaf
# 526  0xcd83055557536eff25fd0eafbc56e74a1b4260b3
# 527  0xe9ac65ca67cf1cd5124d030bbbcb2f9f2b1cf72e
# 528  0xb9ae6510f0582f5f54338b3c4c949ff893c4dc48
#
#                                       Token0 ID Token0 Symbol  \
# 3    0x566957ef80f9fd5526cd2bef8be67035c0b81130          USDC
# 8    0x9abc68b33961268a3ea4116214d7039226de01e1          USDC
# 9    0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 10   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 11   0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0         MATIC
# ..                                          ...           ...
# 524  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 525  0xbc396689893d065f41bc2c6ecbee5e0085233447          PERP
# 526  0xbc396689893d065f41bc2c6ecbee5e0085233447          PERP
# 527  0xbc396689893d065f41bc2c6ecbee5e0085233447          PERP
# 528  0x5c839a10cba8db5122179b05c2135ac8f41038ce           SUI
#
#                                            Token0 Name  \
# 3                            USD Coin (PoS) (Wormhole)
# 8    UltraSuperfuckingDementedgreendildoretardstren...
# 9                                             USD Coin
# 10                                         Wrapped BTC
# 11                                         Matic Token
# ..                                                 ...
# 524                                           USD Coin
# 525                                          Perpetual
# 526                                          Perpetual
# 527                                          Perpetual
# 528                                        SUI Network
#
#                                       Token1 ID Token1 Symbol  \
# 3    0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 8    0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 9    0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f           SNX
# 10   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 11   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# ..                                          ...           ...
# 524  0xbc396689893d065f41bc2c6ecbee5e0085233447          PERP
# 525  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 526  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 527  0xdac17f958d2ee523a2206206994597c13d831ec7          USDT
# 528  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
#
#                  Token1 Name    Volume USD       TVL USD
# 3                   USD Coin  3.715274e+06  1.855657e+02
# 8              Wrapped Ether  1.750676e+07  3.195620e+05
# 9    Synthetix Network Token  1.121544e+08  6.130743e+08
# 10                  USD Coin  3.276979e+05  6.130743e+08
# 11                  USD Coin  1.196317e+08  6.130743e+08
# ..                       ...           ...           ...
# 524                Perpetual  2.349600e+06  2.495186e+06
# 525            Wrapped Ether  4.912814e+01  2.495186e+06
# 526            Wrapped Ether  8.258626e+08  2.495186e+06
# 527               Tether USD  1.999999e+00  2.495186e+06
# 528            Wrapped Ether  4.140726e+03  1.586658e-01
#
# [170 rows x 13 columns]

# %%
df.sort_values("TVL USD", ascending=False).groupby("Token Symbol").head(2)
# Out:
#                 Chain Token Symbol             Token Name  \
# 128  Ethereum Mainnet         WETH          Wrapped Ether
# 111  Ethereum Mainnet         WETH          Wrapped Ether
# 44   Ethereum Mainnet         USDC               USD Coin
# 32   Ethereum Mainnet         USDC               USD Coin
# 64   Ethereum Mainnet         WBTC            Wrapped BTC
# 60   Ethereum Mainnet         WBTC            Wrapped BTC
# 473  Ethereum Mainnet         LINK        ChainLink Token
# 471  Ethereum Mainnet         LINK        ChainLink Token
# 523  Ethereum Mainnet         PERP              Perpetual
# 524  Ethereum Mainnet         PERP              Perpetual
# 272  Ethereum Mainnet         AGLD         Adventure Gold
# 271  Ethereum Mainnet         AGLD         Adventure Gold
# 299  Ethereum Mainnet          INJ        Injective Token
# 300  Ethereum Mainnet          INJ        Injective Token
# 518  Ethereum Mainnet          STG          StargateToken
# 514  Ethereum Mainnet          STG          StargateToken
# 266  Ethereum Mainnet         SAFE             Safe Token
# 265  Ethereum Mainnet         SAFE             Safe Token
# 162  Ethereum Mainnet       WALLET          Ambire Wallet
# 163  Ethereum Mainnet       WALLET          Ambire Wallet
# 189  Ethereum Mainnet          UMA    UMA Voting Token v1
# 186  Ethereum Mainnet          UMA    UMA Voting Token v1
# 346  Ethereum Mainnet        FORTH  Ampleforth Governance
# 347  Ethereum Mainnet        FORTH  Ampleforth Governance
# 239  Ethereum Mainnet          XTP                    Tap
# 238  Ethereum Mainnet          XTP                    Tap
# 394  Ethereum Mainnet          BGB                BG Bond
# 424  Ethereum Mainnet         RARE              SuperRare
# 426  Ethereum Mainnet         RARE              SuperRare
# 338  Ethereum Mainnet          GET                    GET
# 339  Ethereum Mainnet          GET                    GET
# 319  Ethereum Mainnet           FX             Function X
# 320  Ethereum Mainnet           FX             Function X
# 478  Ethereum Mainnet          NCT                 Nectar
# 477  Ethereum Mainnet          NCT                 Nectar
# 396  Ethereum Mainnet          AMP                    Amp
# 397  Ethereum Mainnet          AMP                    Amp
# 494  Ethereum Mainnet     HOTCROSS        Hot Cross Token
# 495  Ethereum Mainnet     HOTCROSS        Hot Cross Token
# 282  Ethereum Mainnet         CUBE    Somnium Space Cubes
# 528  Ethereum Mainnet          SUI            SUI Network
# 91   Ethereum Mainnet          ETH                    ETH
#
#                                        Token ID  \
# 128  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 111  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 44   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 32   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 64   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 60   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# 473  0x514910771af9ca656af840dff83e8264ecf986ca
# 471  0x514910771af9ca656af840dff83e8264ecf986ca
# 523  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 524  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 272  0x32353a6c91143bfd6c7d363b546e62a9a2489a20
# 271  0x32353a6c91143bfd6c7d363b546e62a9a2489a20
# 299  0xe28b3b32b6c345a34ff64674606124dd5aceca30
# 300  0xe28b3b32b6c345a34ff64674606124dd5aceca30
# 518  0xaf5191b0de278c7286d6c7cc6ab6bb8a73ba2cd6
# 514  0xaf5191b0de278c7286d6c7cc6ab6bb8a73ba2cd6
# 266  0x5afe3855358e112b5647b952709e6165e1c1eeee
# 265  0x5afe3855358e112b5647b952709e6165e1c1eeee
# 162  0x88800092ff476844f74dc2fc427974bbee2794ae
# 163  0x88800092ff476844f74dc2fc427974bbee2794ae
# 189  0x04fa0d235c4abf4bcf4787af4cf447de572ef828
# 186  0x04fa0d235c4abf4bcf4787af4cf447de572ef828
# 346  0x77fba179c79de5b7653f68b5039af940ada60ce0
# 347  0x77fba179c79de5b7653f68b5039af940ada60ce0
# 239  0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc
# 238  0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc
# 394  0x6731c740494b1c77d9b1598eb6f8fc317ede0c15
# 424  0xba5bde662c17e2adff1075610382b9b691296350
# 426  0xba5bde662c17e2adff1075610382b9b691296350
# 338  0x8a854288a5976036a725879164ca3e91d30c6a1b
# 339  0x8a854288a5976036a725879164ca3e91d30c6a1b
# 319  0x8c15ef5b4b21951d50e53e4fbda8298ffad25057
# 320  0x8c15ef5b4b21951d50e53e4fbda8298ffad25057
# 478  0x9e46a38f5daabe8683e10793b06749eef7d733d1
# 477  0x9e46a38f5daabe8683e10793b06749eef7d733d1
# 396  0xff20817765cb7f73d4bde2e66e067e58d11095c2
# 397  0xff20817765cb7f73d4bde2e66e067e58d11095c2
# 494  0x4297394c20800e8a38a619a243e9bbe7681ff24e
# 495  0x4297394c20800e8a38a619a243e9bbe7681ff24e
# 282  0xdf801468a808a32656d2ed2d2d80b72a129739f4
# 528  0x5c839a10cba8db5122179b05c2135ac8f41038ce
# 91   0x5884658a803a3655e8955b202cad9956339649dc
#
#                                         Pool ID  \
# 128  0x60594a405d53811d3bc4766596efd80fd545a270
# 111  0x04916039b1f59d9745bf6e0a21f191d1e0a84287
# 44   0xbb256c2f1b677e27118b0345fd2b3894d2e6d487
# 32   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 64   0x4585fe77225b41b697c938b018e2ac67ac5a20c0
# 60   0x15c11b1e07cb763ab75723bb55877b36f56c39b1
# 473  0xd92ba9b67b74305b5534abd2b1f5119b59b24871
# 471  0xcfc389e23728f72558eee13d04b326ddcdd88be3
# 523  0x1eefc75cc4458e651480e80d74b263b77a93cb11
# 524  0x56027930bdff39faf295a7cf6bb94b9bb9f6a718
# 272  0x5d752f322befb038991579972e912b02f61a3dda
# 271  0x5c4bdf44f753b30fe9f5f84ce3e9edc022351098
# 299  0x4858c96a9024fbd7efbfe78aa5a8d62900952420
# 300  0x6c063a6e8cd45869b5eb75291e65a3de298f3aa8
# 518  0xd6a309f49cf79542cea91df7b334eb4bd29aa0d7
# 514  0x035f1d7d2520d24c6e8b06758316290df06b8c82
# 266  0xbb0eccb680ff8b2cbbb239b200cc6f9927b4aacb
# 265  0x486db7c399f11c6207cddaa900dedd5852df109d
# 162  0x53bbdf4ea397d17a6f904dc882b3fb78a6875a66
# 163  0x81e4be51d858362f38f94949f53083a83f536f0b
# 189  0xbb947145783c93124c666933aa9abd30deec1934
# 186  0x157dfa656fdf0d18e1ba94075a53600d81cb3a97
# 346  0x06783fe89bf5906cc48c2c53f73a99fc82996ead
# 347  0x406113a76bdedb4a0333ff3d0b80c46b3035b655
# 239  0x66ad25b5aa3543cb7f4566851fe26da6abab205e
# 238  0x3ebf581edd7043468cd7cd0f4b3ab34283ffb04e
# 394  0xe6d5953b3a70c4a59bbe51e27505ed3dddb5d80a
# 424  0x3fca856ff6c17af1cce4c0f563de1bbb4fb01403
# 426  0xc844109b99b6536376f8571376894eca5313798a
# 338  0x02469e30dd450de2e9de00d49d679f1d1d774ada
# 339  0x03581d0902c442e977438cb700df450db98b464b
# 319  0x159f8402acb30ce6334fc8918ede033e8e0d36df
# 320  0xb03f87e577c4fe4685cf2c88a8473414bb1d04f1
# 478  0xd73fc3cef30f7d96d18d8b4bfaa7768b61805e03
# 477  0xa884e01d1da92fd16b972e5c2ade7c595391b5ee
# 396  0x0221d724c1a37b8c54dd99fefddae2b903d193d6
# 397  0x1ad6fbe0cbe1ecdc5ca8c349773e65dade2a5acb
# 494  0x7638a67a9ae3f98e5596773619a98c0984a8b267
# 495  0xb280811d450141bcaf5649d390ddaeb3914a1051
# 282  0x9e5bfb074aa3a90daf84484f9e099ad39d64d578
# 528  0xb9ae6510f0582f5f54338b3c4c949ff893c4dc48
# 91   0x1974f23344bf728fc5e0d5a04ca8e2b0a6533de4
#
#                                       Token0 ID Token0 Symbol  \
# 128  0x6b175474e89094c44da98b954eedeac495271d0f           DAI
# 111  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e           YFI
# 44   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 32   0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 64   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 60   0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# 473  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e           YFI
# 471  0x514910771af9ca656af840dff83e8264ecf986ca          LINK
# 523  0xbc396689893d065f41bc2c6ecbee5e0085233447          PERP
# 524  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 272  0x32353a6c91143bfd6c7d363b546e62a9a2489a20          AGLD
# 271  0x32353a6c91143bfd6c7d363b546e62a9a2489a20          AGLD
# 299  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 300  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 518  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 514  0xaf5191b0de278c7286d6c7cc6ab6bb8a73ba2cd6           STG
# 266  0x5afe3855358e112b5647b952709e6165e1c1eeee          SAFE
# 265  0x5afe3855358e112b5647b952709e6165e1c1eeee          SAFE
# 162  0x88800092ff476844f74dc2fc427974bbee2794ae        WALLET
# 163  0x88800092ff476844f74dc2fc427974bbee2794ae        WALLET
# 189  0x04fa0d235c4abf4bcf4787af4cf447de572ef828           UMA
# 186  0x04fa0d235c4abf4bcf4787af4cf447de572ef828           UMA
# 346  0x77fba179c79de5b7653f68b5039af940ada60ce0         FORTH
# 347  0x77fba179c79de5b7653f68b5039af940ada60ce0         FORTH
# 239  0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc           XTP
# 238  0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc           XTP
# 394  0x6731c740494b1c77d9b1598eb6f8fc317ede0c15           BGB
# 424  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 426  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 338  0x8a854288a5976036a725879164ca3e91d30c6a1b           GET
# 339  0x8a854288a5976036a725879164ca3e91d30c6a1b           GET
# 319  0x8c15ef5b4b21951d50e53e4fbda8298ffad25057            FX
# 320  0x8c15ef5b4b21951d50e53e4fbda8298ffad25057            FX
# 478  0x9e46a38f5daabe8683e10793b06749eef7d733d1           NCT
# 477  0x9e46a38f5daabe8683e10793b06749eef7d733d1           NCT
# 396  0x6b175474e89094c44da98b954eedeac495271d0f           DAI
# 397  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# 494  0x4297394c20800e8a38a619a243e9bbe7681ff24e      HOTCROSS
# 495  0x4297394c20800e8a38a619a243e9bbe7681ff24e      HOTCROSS
# 282  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# 528  0x5c839a10cba8db5122179b05c2135ac8f41038ce           SUI
# 91   0x5884658a803a3655e8955b202cad9956339649dc           ETH
#
#                Token0 Name                                   Token1 ID  \
# 128         Dai Stablecoin  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 111          yearn.finance  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 44                USD Coin  0xdac17f958d2ee523a2206206994597c13d831ec7
# 32                USD Coin  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 64             Wrapped BTC  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 60             Wrapped BTC  0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f
# 473          yearn.finance  0x514910771af9ca656af840dff83e8264ecf986ca
# 471        ChainLink Token  0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0
# 523              Perpetual  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 524               USD Coin  0xbc396689893d065f41bc2c6ecbee5e0085233447
# 272         Adventure Gold  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 271         Adventure Gold  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 299          Wrapped Ether  0xe28b3b32b6c345a34ff64674606124dd5aceca30
# 300          Wrapped Ether  0xe28b3b32b6c345a34ff64674606124dd5aceca30
# 518               USD Coin  0xaf5191b0de278c7286d6c7cc6ab6bb8a73ba2cd6
# 514          StargateToken  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 266             Safe Token  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 265             Safe Token  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 162          Ambire Wallet  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 163          Ambire Wallet  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 189    UMA Voting Token v1  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 186    UMA Voting Token v1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 346  Ampleforth Governance  0xdac17f958d2ee523a2206206994597c13d831ec7
# 347  Ampleforth Governance  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 239                    Tap  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 238                    Tap  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 394                BG Bond  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 424               USD Coin  0xba5bde662c17e2adff1075610382b9b691296350
# 426               USD Coin  0xba5bde662c17e2adff1075610382b9b691296350
# 338                    GET  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 339                    GET  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 319             Function X  0xdac17f958d2ee523a2206206994597c13d831ec7
# 320             Function X  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 478                 Nectar  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 477                 Nectar  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 396         Dai Stablecoin  0xff20817765cb7f73d4bde2e66e067e58d11095c2
# 397               USD Coin  0xff20817765cb7f73d4bde2e66e067e58d11095c2
# 494        Hot Cross Token  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 495        Hot Cross Token  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 282          Wrapped Ether  0xdf801468a808a32656d2ed2d2d80b72a129739f4
# 528            SUI Network  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 91                     ETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#     Token1 Symbol              Token1 Name    Volume USD       TVL USD
# 128          WETH            Wrapped Ether  3.025558e+10  2.115144e+09
# 111          WETH            Wrapped Ether  3.176280e+08  2.115144e+09
# 44           USDT               Tether USD  2.214721e+05  6.130743e+08
# 32           WETH            Wrapped Ether  4.730828e+11  6.130743e+08
# 64           WETH            Wrapped Ether  6.782049e+10  3.589768e+08
# 60            SNX  Synthetix Network Token  4.374002e+05  3.589768e+08
# 473          LINK          ChainLink Token  1.030134e+03  3.489161e+07
# 471         MATIC              Matic Token  1.607353e+04  3.489161e+07
# 523          WETH            Wrapped Ether  3.685471e+07  2.495186e+06
# 524          PERP                Perpetual  2.349600e+06  2.495186e+06
# 272          WETH            Wrapped Ether  1.110849e+09  1.986805e+06
# 271          WETH            Wrapped Ether  1.327646e+05  1.986805e+06
# 299           INJ          Injective Token  1.531869e+07  1.877860e+06
# 300           INJ          Injective Token  6.275993e+08  1.877860e+06
# 518           STG            StargateToken  2.614234e+08  1.840773e+06
# 514          WETH            Wrapped Ether  5.398462e+06  1.840773e+06
# 266          WETH            Wrapped Ether  5.957764e+07  1.527395e+06
# 265          USDC                 USD Coin  5.190961e+05  1.527395e+06
# 162          WETH            Wrapped Ether  4.958613e+06  6.161838e+05
# 163          WETH            Wrapped Ether  4.227243e+04  6.161838e+05
# 189          USDC                 USD Coin  9.688880e+04  3.907222e+05
# 186          WETH            Wrapped Ether  2.293128e+08  3.907222e+05
# 346          USDT               Tether USD  3.880029e+04  3.587417e+05
# 347          WETH            Wrapped Ether  2.858217e+04  3.587417e+05
# 239          WETH            Wrapped Ether  3.042858e+07  3.101147e+05
# 238          WETH            Wrapped Ether  3.186270e+05  3.101147e+05
# 394          WETH            Wrapped Ether  1.443633e+03  2.987913e+05
# 424          RARE                SuperRare  4.034043e+04  2.512893e+05
# 426          RARE                SuperRare  4.951885e+05  2.512893e+05
# 338          WETH            Wrapped Ether  3.360009e+07  1.518641e+05
# 339          USDC                 USD Coin  2.405608e+02  1.518641e+05
# 319          USDT               Tether USD  1.086432e+06  1.511566e+05
# 320          WETH            Wrapped Ether  3.528452e+08  1.511566e+05
# 478          USDC                 USD Coin  7.135348e+04  1.128767e+05
# 477          USDC                 USD Coin  1.692874e+01  1.128767e+05
# 396           AMP                      Amp  1.313633e+05  8.978021e+04
# 397           AMP                      Amp  3.669187e+06  8.978021e+04
# 494          WETH            Wrapped Ether  4.184053e+04  3.983417e+04
# 495          USDC                 USD Coin  7.814039e+06  3.983417e+04
# 282          CUBE      Somnium Space Cubes  6.422880e+07  3.574762e+04
# 528          WETH            Wrapped Ether  4.140726e+03  1.586658e-01
# 91           WETH            Wrapped Ether  4.740474e+04  1.006896e-13

# %%
for name, group in df.groupby("Token0 Symbol"):
    print(name)
    # print address
    print(group["Token0 ID"].values[0])

    # print pair
# Out:
# 1INCH
# 0x111111111117dc0aa78b770fa6a738034120c302
# 1INCH Token
# 613074273.41451
# AAVE
# 0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9
# Aave Token
# 613074273.41451
# AGLD
# 0x32353a6c91143bfd6c7d363b546e62a9a2489a20
# Adventure Gold
# 1986804.903946648
# AKRO
# 0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7
# Akropolis
# 0.0
# ALICE
# 0xac51066d7bec65dc4589368da368b212745d63e8
# ALICE
# 0.0
# ALL
# 0x913749155f1378fa482f5d2889fde3ada3b7515c
# OrdinallDAO
# 0.0
# ALPHA
# 0x146d0fff5be0c7825f47ca0359c3070b12a4684b
# Alpha
# 0.0
# AMPL
# 0xd46ba6d942050d489dbd938a2c909a5d5039a161
# Ampleforth
# 0.0
# APL
# 0x60f886c6fd97aa59e9e1e81cf5f51c4a25c6cd2d
# Approximate Labs
# 0.0
# ASM
# 0x2565ae0385659badcada1031db704442e1b69982
# ASSEMBLE
# 0.0
# AVA
# 0xa6c0c097741d55ecd9a3a7def3a8253fd022ceb9
# AVA
# 0.0
# AVT
# 0x0d88ed6e74bbfd96b831231638b66c05571e824f
#
# 0.0
# BCUG
# 0x14da7b27b2e0fedefe0a664118b0c9bc68e2e9af
# Blockchain Cuties Universe Governance Token
# 0.0
# BDX
# 0x709e46ce1eb677c3beccc32a27a2e71eaaf7a7be
# BODAX
# 0.0
# BEND
# 0x0d02755a5700414b26ff040e1de35d337df56218
# Bend Token
# 0.0
# BGB
# 0x6731c740494b1c77d9b1598eb6f8fc317ede0c15
# BG Bond
# 298791.2941612456
# BLANK
# 0x41a3dba3d677e573636ba691a70ff2d606c29666
# GoBlank Token
# 0.0
# BOND
# 0x0391d2021f89dc339f60fff84546ea23e337750f
# BarnBridge Governance Token
# 0.0
# BONK
# 0x20fe1c00a6c6674440a2ee345ba11fdaf098f9ee
# BONKLER
# 0.0
# BOTTO
# 0x9dfad1b7102d46b1b197b90095b5c4e9f5845bba
# Botto
# 0.0
# BST
# 0x0b4680e848f842b86e4df38d9fa0d9f9419f37ec
# Beshare Token
# 0.0
# BTC2
# 0x8588bb523bfd86426dabaa99a9e7497969a570c5
# btc2.lol
# 0.0
# BTS
# 0x324b23a4b70eb3d70a3d5534d53e2bebab6a240d
# BTS
# 0.0
# BUNNY
# 0x3a20ca0f231dc44ad4b0dee93456cb65420dd0a9
# Bunny Race
# 0.0
# BURGER
# 0x0b66138cdb455339c1343438fe401d0fae05110b
# Burger DAO
# 0.0
# BURN
# 0x52e7b23e1faba6d83376725e2ccad75efbd8736e
# BURN
# 0.0
# BXX
# 0x6b1a8f210ec6b7b6643cea3583fb0c079f367898
# Baanx
# 0.0
# C20
# 0x26e75307fc0c021472feb8f727839531f112f317
# Crypto20
# 0.0
# CERE
# 0x2da719db753dfa10a62e140f436e1d67f2ddb0d6
# CERE Network
# 0.0
# CHI
# 0x0000000000004946c0e9f43f4dee607b0ef1fa1c
# Chi Gastoken by 1inch
# 0.0
# COMP
# 0xc00e94cb662c3520282e6f5717214004a7f26888
# Compound
# 2115143594.4969866
# CREAM
# 0x2ba592f78db6436527729929aaf6c908497cb200
# Cream
# 0.0
# CTT
# 0xae869fada7cd6979bd111b60b96767916de2f2db
# Colibri Trade Token
# 0.0
# CUBE
# 0x133e7747f1d8e33ed784a536381b5405c78e24e1
# AllSpark Coin
# 0.0
# CWS
# 0xac0104cca91d167873b8601d2e71eb3d4d8c33e0
# Crowns
# 0.0
# DAI
# 0x6b175474e89094c44da98b954eedeac495271d0f
# Dai Stablecoin
# 613074273.41451
# DATA
# 0x0cf0ee63788a0849fe5297f3407f701e122cc023
# Streamr DATAcoin
# 0.0
# DFYN
# 0x9695e0114e12c0d3a3636fab5a18e6b737529023
# DFYN Token
# 0.0
# DIP
# 0x6e4076c74097cd49f3365bb83ebc93ed254963ce
# Dipcoin
# 0.0
# DIVI
# 0x246908bff0b1ba6ecadcf57fb94f6ae2fcd43a77
# Divi
# 0.0
# ECO
# 0x6d13c736bb4f69578e75ccc8e6a6232fadea668d
# EcosystemNetwork
# 0.0
# EPIC
# 0x9fc905e9b0ce4ac83f216a83c57c124b04484387
# EPIC
# 0.0
# EQZ
# 0x1da87b114f35e1dc91f72bf57fc07a768ad40bb0
# Equalizer
# 0.0
# ES
# 0x1960d8a3994444b54814a8f5bcf56a1d5a8e8a68
# ERC-S
# 0.0
# ETH
# 0x065a049b5be75e4f1d29a03c6edb5acc1a4e3b93
# 小学生
# 0.0
# EZ
# 0x00aba6fe5557de1a1d565658cbddddf7c710a1eb
# EASY V2
# 0.0
# FAR
# 0x69442209c17855857a46db66996241c91238faf1
# FOMOARMY
# 0.0
# FEI
# 0x956f47f50a910163d8bf957cf5846d573e7f87ca
# Fei USD
# 613074273.41451
# FLOKI
# 0x1c1deed4c2c4dc95aebbf04907ed17283f9c41b4
# FlokiCoin
# 0.0
# FORTH
# 0x77fba179c79de5b7653f68b5039af940ada60ce0
# Ampleforth Governance
# 358741.6612856494
# FOX
# 0x52ba5b77a8cde2bb28135f88ebb4a6330f12ac80
# Fox DAO
# 0.0
# FX
# 0x8c15ef5b4b21951d50e53e4fbda8298ffad25057
# Function X
# 151156.56203640517
# GAME
# 0x63f88a2298a5c4aee3c216aa6d926b184a4b2437
# GAME Credits
# 0.0
# GET
# 0x8a854288a5976036a725879164ca3e91d30c6a1b
# GET
# 151864.14519897365
# GMT
# 0x488a1590935be1a7113e636439cd8557e6ddcc55
# Gold Mountain Token
# 0.0
# GOG
# 0x8772780b2a94e01a7d973f064c0ff2ff0bae01bb
# GOG
# 0.0
# HBTC
# 0x0316eb71485b0ab14103307bf65a021042c6d380
# Huobi BTC
# 0.0
# HIGH
# 0x48e359e6917f9c2060c612e60b2951b86233bfd7
# HIGH
# 0.0
# HOTCROSS
# 0x4297394c20800e8a38a619a243e9bbe7681ff24e
# Hot Cross Token
# 39834.166767415394
# IDV
# 0x45448e05020576929fcdeabc228e35b420098840
# Idavoll
# 0.0
# IGG
# 0x8ffe40a3d0f80c0ce6b203d5cdc1a6a86d9acaea
# IG Gold
# 0.0
# LEVER
# 0x4b5f49487ea7b3609b1ad05459be420548789f1f
# Lever
# 0.0
# LINK
# 0x514910771af9ca656af840dff83e8264ecf986ca
# ChainLink Token
# 613074273.41451
# LON
# 0x0000000000095413afc295d19edeb1ad7b71c952
# Tokenlon
# 0.0
# MASK
# 0x241357313e802e16eeb9380f2b027224e90b56dd
# MaskDAO
# 0.0
# MATIC
# 0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0
# Matic Token
# 613074273.41451
# MEV
# 0x019ebb81e412d0ec3c917ebc17363755e2e6ec2a
# MEV
# 0.0
# MKR
# 0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2
# Maker
# 613074273.41451
# MNGO
# 0x335e14d18d8a903b782a39059dc35d61b94e1c1b
# Mango INU
# 0.0
# MSTR
# 0xb2b68f7785daecf337749491c4a5ff9de3c964ef
# MicroStrategy
# 0.0
# MTH
# 0x87ad2db2097a16a039e1d830022b4d7f3188c62a
# Methereum
# 0.0
# NBT
# 0x446f2a8a39cc730ef378be759a3c57f1a3fe824c
# NanoByte Token
# 0.0
# NCT
# 0x8a9c4dfe8b9d8962b31e4e16f8321c44d48e246e
# NameChangeToken
# 0.0
# OLE
# 0x92cfbec26c206c90aee3b7c66a9ae673754fab7e
# OpenLeverage
# 0.0
# OM
# 0x3593d125a4f7849a1b059e64f4517a86dd60c95d
# MANTRA DAO
# 0.0
# PBX
# 0xd528cf2e081f72908e086f8800977df826b5a483
# Paribus
# 0.0
# PEAK
# 0x630d98424efe0ea27fb1b3ab7741907dffeaad78
# PEAKDEFI
# 0.0
# PERP
# 0xbc396689893d065f41bc2c6ecbee5e0085233447
# Perpetual
# 2495186.169192208
# PICKLE
# 0x3ec15c4745e21ab3831d1f51c492e3b5582d6239
# PICKLE
# 0.0
# PIT
# 0xb8b97a5a544d6b755aa45feacf3740a578b7df05
# pumpit
# 0.0
# PKF
# 0x8b39b70e39aa811b69365398e0aace9bee238aeb
# PolkaFoundry
# 0.0
# PPAY
# 0x054d64b73d3d8a21af3d764efd76bcaa774f3bb2
# Plasma
# 0.0
# RARE
# 0xba5bde662c17e2adff1075610382b9b691296350
# SuperRare
# 251289.26132726733
# RAY
# 0x5245c0249e5eeb2a0838266800471fd32adb1089
# Raydium
# 0.0
# REQ
# 0x8f8221afbb33998d8584a2b05749ba73c37a938a
# Request Token
# 0.0
# RLC
# 0x589a4c73b69b6a2a5c4e5951c7deee8696ceaead
# Relaunch
# 0.0
# RON
# 0x3267c5b73cc15e253b1a90c01366b17d560bc6fb
# President Ron DeSantis
# 0.0
# SAFE
# 0x03ffed4861caa0ea67f6f64a1399866daed023fa
# Safe Token
# 0.0
# SHIDO
# 0x72c60bfffef18dca51db32b52b819a951b6ddbed
# Shido
# 0.0
# SHPING
# 0x7c84e62859d0715eb77d1b1c4154ecd6abb21bec
# Shping Coin
# 0.0
# SNX
# 0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f
# Synthetix Network Token
# 2115143594.4969866
# SPC
# 0x37af406979ef469c06fd9533a3ef7eabd38631b1
# Soup Coin
# 0.0
# SPH
# 0x4ab4886cdffcad8003c44408afc45b535e089809
# Sapphire
# 0.0
# SPS
# 0x00813e3421e1367353bfe7615c7f7f133c89df74
# Splintershards
# 0.0
# SRK
# 0x0488401c3f535193fa8df029d9ffe615a06e74e6
# SparkPoint
# 0.0
# STG
# 0x86343114a604ea6e85f027bd1c08e425d1001b85
# STARGATE
# 0.0
# STORJ
# 0xb64ef51c888972c908cfacf59b47c1afbc0ab8ac
# StorjToken
# 0.0
# STOS
# 0x08c32b0726c5684024ea6e141c50ade9690bbdcc
# Stratos Token
# 0.0
# STRP
# 0x97872eafd79940c7b24f7bcc1eadb1457347adc9
# Strips Token
# 0.0
# SUI
# 0x5c839a10cba8db5122179b05c2135ac8f41038ce
# SUI Network
# 0.15866578294960587
# SXP
# 0x8ce9137d39326ad0cd6491fb5cc0cba0e089b6a9
# Swipe
# 0.0
# TCP
# 0x06576eb3b212d605b797dc15523d9dc9f4f66db4
# The Crypto Prophecies
# 0.0
# TUNE
# 0x1fac00ccee478eced6a120a50ed2ab28ee7fe32b
# Bitune AI Platform Token
# 0.0
# TUSD
# 0x0000000000085d4780b73119b644ae5ecd22b376
# TrueUSD
# 613074273.41451
# UFT
# 0x0202be363b8a4820f3f4de7faf5224ff05943ab1
# UniLend Finance Token
# 0.0
# UMA
# 0x04fa0d235c4abf4bcf4787af4cf447de572ef828
# UMA Voting Token v1
# 390722.1909907639
# UNO
# 0x57190debae526cd140074291f07b5be5a32b010e
# UNO 100X
# 0.0
# USDC
# 0x2329805e68e3f1b64f7cf656366b2973a69d7b43
# USDC
# 0.0
# USDT
# 0xdac17f958d2ee523a2206206994597c13d831ec7
# Tether USD
# 0.0
# VLX
# 0x8c543aed163909142695f2d2acd0d55791a9edb9
# VLX
# 0.0
# VOLT
# 0x559ebc30b0e58a45cc9ff573f77ef1e5eb1b3e18
# VOLT
# 0.0
# VR
# 0x7d5121505149065b562c789a0145ed750e6e8cdd
# Victoria VR
# 0.0
# WAGMIGAMES
# 0x3b604747ad1720c01ded0455728b62c0d2f100f0
# WAGMI GAMES
# 0.0
# WALLET
# 0x88800092ff476844f74dc2fc427974bbee2794ae
# Ambire Wallet
# 616183.8270549575
# WBTC
# 0x2260fac5e5542a773aa44fbcfedf7c193bc2c599
# Wrapped BTC
# 613074273.41451
# WETH
# 0x05011bfa5d8f70b53a5b1333cceaaf67cf364d44
# wrapped ether
# 0.0
# WOZX
# 0x34950ff2b487d9e5282c5ab342d08a2f712eb79f
# EFFORCE IEO
# 0.0
# XTP
# 0x6368e1e18c4c419ddfc608a0bed1ccb87b9250fc
# Tap
# 310114.7237934517
# YFI
# 0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e
# yearn.finance
# 613074273.41451
# cDAI
# 0x5d3a536e4d6dbd6114cc1ead35777bab948e3643
# Compound Dai
# 2115143594.4969866
# cUSDC
# 0x39aa39c021dfbae8fac545936693ac917d5e7563
# Compound USD Coin
# 613074273.41451
# sUSD
# 0x57ab1ec28d129707052df4df418d58a2d46d5f51
# Synth sUSD
# 613074273.41451

# %%
selected_pools_df = (
    df.sort_values("Volume USD", ascending=False)
    .groupby("pair_name")
    .first()
    .sort_values("Volume USD", ascending=False)
)

print(len(selected_pools_df))
selected_pools_df
# Out:
# 66
#                       Chain Token Symbol      Token Name  \
# pair_name
# USDC/WETH  Ethereum Mainnet         USDC        USD Coin
# WETH/USDT  Ethereum Mainnet         USDT      Tether USD
# USDC/USDT  Ethereum Mainnet         USDC        USD Coin
# WBTC/WETH  Ethereum Mainnet         WETH   Wrapped Ether
# DAI/WETH   Ethereum Mainnet         WETH   Wrapped Ether
# ...                     ...          ...             ...
# sUSD/WETH  Ethereum Mainnet         WETH   Wrapped Ether
# ETH/WETH   Ethereum Mainnet          ETH             ETH
# cDAI/WETH  Ethereum Mainnet         WETH   Wrapped Ether
# AGLD/USDC  Ethereum Mainnet         AGLD  Adventure Gold
# SNX/USDT   Ethereum Mainnet         USDT      Tether USD
#
#                                              Token ID  \
# pair_name
# USDC/WETH  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# WETH/USDT  0xdac17f958d2ee523a2206206994597c13d831ec7
# USDC/USDT  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# WBTC/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# DAI/WETH   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ...                                               ...
# sUSD/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ETH/WETH   0x5884658a803a3655e8955b202cad9956339649dc
# cDAI/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# AGLD/USDC  0x32353a6c91143bfd6c7d363b546e62a9a2489a20
# SNX/USDT   0xdac17f958d2ee523a2206206994597c13d831ec7
#
#                                               Pool ID  \
# pair_name
# USDC/WETH  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# WETH/USDT  0x11b815efb8f581194ae79006d24e0d814b7697f6
# USDC/USDT  0x3416cf6c708da44db2624d63ea0aaef7113527c6
# WBTC/WETH  0x4585fe77225b41b697c938b018e2ac67ac5a20c0
# DAI/WETH   0x60594a405d53811d3bc4766596efd80fd545a270
# ...                                               ...
# sUSD/WETH  0x6e2a6e92d1c0df4fbf7b35e9aebf2e681c9e6f5f
# ETH/WETH   0x1974f23344bf728fc5e0d5a04ca8e2b0a6533de4
# cDAI/WETH  0x82bd0e16516f828a0616038002e152aa6f27aedc
# AGLD/USDC  0xdc0e2f43d1f2ad55031b5333e48cf51728548530
# SNX/USDT   0x398695ceb1e044207e93cc430273b138ca727a8f
#
#                                             Token0 ID Token0 Symbol  \
# pair_name
# USDC/WETH  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# WETH/USDT  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# USDC/USDT  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# WBTC/WETH  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599          WBTC
# DAI/WETH   0x6b175474e89094c44da98b954eedeac495271d0f           DAI
# ...                                               ...           ...
# sUSD/WETH  0x57ab1ec28d129707052df4df418d58a2d46d5f51          sUSD
# ETH/WETH   0x5884658a803a3655e8955b202cad9956339649dc           ETH
# cDAI/WETH  0x5d3a536e4d6dbd6114cc1ead35777bab948e3643          cDAI
# AGLD/USDC  0x32353a6c91143bfd6c7d363b546e62a9a2489a20          AGLD
# SNX/USDT   0xc011a73ee8576fb46f5e1c5751ca3b9fe0af2a6f           SNX
#
#                        Token0 Name  \
# pair_name
# USDC/WETH                 USD Coin
# WETH/USDT            Wrapped Ether
# USDC/USDT                 USD Coin
# WBTC/WETH              Wrapped BTC
# DAI/WETH            Dai Stablecoin
# ...                            ...
# sUSD/WETH               Synth sUSD
# ETH/WETH                       ETH
# cDAI/WETH             Compound Dai
# AGLD/USDC           Adventure Gold
# SNX/USDT   Synthetix Network Token
#
#                                             Token1 ID Token1 Symbol  \
# pair_name
# USDC/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# WETH/USDT  0xdac17f958d2ee523a2206206994597c13d831ec7          USDT
# USDC/USDT  0xdac17f958d2ee523a2206206994597c13d831ec7          USDT
# WBTC/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# DAI/WETH   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# ...                                               ...           ...
# sUSD/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# ETH/WETH   0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# cDAI/WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2          WETH
# AGLD/USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48          USDC
# SNX/USDT   0xdac17f958d2ee523a2206206994597c13d831ec7          USDT
#
#              Token1 Name    Volume USD       TVL USD
# pair_name
# USDC/WETH  Wrapped Ether  4.730827e+11  6.130151e+08
# WETH/USDT     Tether USD  9.516109e+10  2.500036e+08
# USDC/USDT     Tether USD  8.027196e+10  6.130151e+08
# WBTC/WETH  Wrapped Ether  6.782041e+10  2.115345e+09
# DAI/WETH   Wrapped Ether  3.025558e+10  2.115345e+09
# ...                  ...           ...           ...
# sUSD/WETH  Wrapped Ether  5.563937e+04  2.115345e+09
# ETH/WETH   Wrapped Ether  4.740474e+04  1.006896e-13
# cDAI/WETH  Wrapped Ether  9.906405e+03  2.115345e+09
# AGLD/USDC       USD Coin  5.845697e+03  1.986805e+06
# SNX/USDT      Tether USD  1.325031e+03  2.500036e+08
#
# [66 rows x 13 columns]
